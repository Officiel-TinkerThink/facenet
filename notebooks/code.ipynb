# %%
import pandas as pd
from pathlib import Path
import os
import sys

# %%
sys.path.append('..')

# %%
len(sys.path)
# Out:
# 11

# %%
sys.path
# Out:
# ['c:\\Users\\HP\\anaconda3\\envs\\torch-gpu\\python311.zip',
#  'c:\\Users\\HP\\anaconda3\\envs\\torch-gpu\\DLLs',
#  'c:\\Users\\HP\\anaconda3\\envs\\torch-gpu\\Lib',
#  'c:\\Users\\HP\\anaconda3\\envs\\torch-gpu',
#  '',
#  'C:\\Users\\HP\\AppData\\Roaming\\Python\\Python311\\site-packages',
#  'c:\\Users\\HP\\anaconda3\\envs\\torch-gpu\\Lib\\site-packages',
#  'c:\\Users\\HP\\anaconda3\\envs\\torch-gpu\\Lib\\site-packages\\win32',
#  'c:\\Users\\HP\\anaconda3\\envs\\torch-gpu\\Lib\\site-packages\\win32\\lib',
#  'c:\\Users\\HP\\anaconda3\\envs\\torch-gpu\\Lib\\site-packages\\Pythonwin',
#  '..']

# %%
from dataset.dataset import CelebADataset

# %%
labels = pd.read_csv("../data/celeba/list_eval_partition.csv", sep=",", header=0, names=["image", "split"]).head()
labels
# Out:
#         image  split
# 0  000001.jpg      0
# 1  000002.jpg      0
# 2  000003.jpg      0
# 3  000004.jpg      0
# 4  000005.jpg      0

# %%
images = pd.read_csv("../data/celeba/identity_CelebA.txt", sep=" ", header=None, names=["image", "personal_id"]).head()
images
# Out:
#         image  personal_id
# 0  000001.jpg         2880
# 1  000002.jpg         2937
# 2  000003.jpg         8692
# 3  000004.jpg         5805
# 4  000005.jpg         9295

# %%
merged = pd.merge(images, labels, on='image')
merged
# Out:
#         image  personal_id  split
# 0  000001.jpg         2880      0
# 1  000002.jpg         2937      0
# 2  000003.jpg         8692      0
# 3  000004.jpg         5805      0
# 4  000005.jpg         9295      0
