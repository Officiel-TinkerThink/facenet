# %%
import torch

# %%
A = torch.tensor([[1,1], [2,1], [0,2]])
A
# Out:
# tensor([[1, 1],
#         [2, 1],
#         [0, 2]])

# %%
A.t()
# Out:
# tensor([[1, 2, 0],
#         [1, 1, 2]])

# %%
dot = torch.matmul(A, A.t())
dot
# Out:
# tensor([[2, 3, 2],
#         [3, 5, 2],
#         [2, 2, 4]])

# %%
square_norm = torch.diag(dot)
square_norm
# Out:
# tensor([2, 5, 4])

# %%
square_norm.unsqueeze(0) - 2 * dot + square_norm.unsqueeze(1)
# Out:
# tensor([[0, 1, 2],
#         [1, 0, 5],
#         [2, 5, 0]])
